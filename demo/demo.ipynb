# %% [markdown]
# ### import and path

# %%
import socket
import sys
import pickle
import os
import time
from pprint import pprint

sys.path.append('/home/zhengyu/workspace/urban_planning/')
home_dir= '/home/zhengyu/'
root_dir = '/data/zhengyu/urban_planning/'

# %% [markdown]
# ### demo

# %%
from urban_planning.envs import CityEnv
from urban_planning.envs import city_config
from urban_planning.utils.config import Config

# %%
id = 'dhm'
seed = 666
temp = False
cfg = Config(id, seed, temp, root_dir)
env = CityEnv(cfg)

# %%
model_path = os.path.join(root_dir, id, str(seed), 'models', 'best.p')
d = pickle.load(open(model_path, 'rb'))
gdf = d['best_plans'][0]['gdf']
print(d['best_plans'][0])
# Out:
# {'road_network': -1.0, 'life_circle': 0.7636911454638966, 'greenness': 0.8976211954204096, 'concept': -1.0, 'life_circle_info': {'life_circle_15min': 0.9612903225806452, 'life_circle_10min': 0.7483870967741937, 'life_circle_5min': 0.3548387096774194, 'decentralization_reward': 0.3060809737940586, 'utility': 0.2610552150878087, 'shopping': 0.7741935483870968, 'working': 0.6774193548387096, 'education': 0.8709677419354839, 'medical care': 0.7741935483870968, 'entertainment': 0.6451612903225806}, 'concept_info': {}, 'land_use_reward': 3.952385777275996, 'gdf':      type  existence                                           geometry  \
# id
# 0       2       True            LINESTRING (0.000 0.000, 432.000 0.000)
# 1       2       True         LINESTRING (432.000 0.000, 1224.000 0.000)
# 2       2       True        LINESTRING (1224.000 0.000, 1867.000 0.000)
# 3       2      False  LINESTRING (0.000 2768.000, 0.000 2596.442, 0....
# 4       2       True        LINESTRING (0.000 2414.000, 0.000 1932.000)
# ..    ...        ...                                                ...
# 460     2       True   LINESTRING (1032.123 808.000, 1032.123 1025.682)
# 461     5       True  POLYGON ((1032.123 1025.682, 1132.123 1025.682...
# 462     8       True  POLYGON ((933.000 1122.000, 1033.000 1122.000,...
# 463     5       True  POLYGON ((1463.000 942.000, 1535.000 942.000, ...
# 464     5       True  POLYGON ((1545.000 1815.000, 1663.000 1815.000...
#
#          rect       eqi        sc
# id
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# ..        ...       ...       ...
# 460       NaN       NaN       NaN
# 461  1.000000  1.000000  0.862774
# 462  0.542887  0.736809  0.542103
# 463  1.000000  1.000000  0.808594
# 464  0.767369  0.972285  0.945190
#
# [465 rows x 6 columns], 'land_use_gdf':      type  existence                                           geometry  \
# id
# 0       2       True            LINESTRING (0.000 0.000, 432.000 0.000)
# 1       2       True         LINESTRING (432.000 0.000, 1224.000 0.000)
# 2       2       True        LINESTRING (1224.000 0.000, 1867.000 0.000)
# 3       2      False  LINESTRING (0.000 2768.000, 0.000 2596.442, 0....
# 4       2       True        LINESTRING (0.000 2414.000, 0.000 1932.000)
# ..    ...        ...                                                ...
# 460     3       True   LINESTRING (1032.123 808.000, 1032.123 1025.682)
# 461     5       True  POLYGON ((1032.123 1025.682, 1132.123 1025.682...
# 462     8       True  POLYGON ((933.000 1122.000, 1033.000 1122.000,...
# 463     5       True  POLYGON ((1463.000 942.000, 1535.000 942.000, ...
# 464     5       True  POLYGON ((1545.000 1815.000, 1663.000 1815.000...
#
#          rect       eqi        sc
# id
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN
# ..        ...       ...       ...
# 460       NaN       NaN       NaN
# 461  1.000000  1.000000  0.862774
# 462  0.542887  0.736809  0.542103
# 463  1.000000  1.000000  0.808594
# 464  0.767369  0.972285  0.945190
#
# [465 rows x 6 columns]}

# %% [markdown]
# ### load plan and score

# %%
env.load_plan(gdf)
env.score_plan()
# Out:
# reward: 3.952385777275996
# {   'road_network': -1.0,
#     'life_circle': 0.7636911454638966,
#     'greenness': 0.8976211954204096,
#     'road_network_info': {},
#     'life_circle_info': {   'life_circle_15min': 0.9612903225806452,
#                             'life_circle_10min': 0.7483870967741937,
#                             'life_circle_5min': 0.3548387096774194,
#                             'decentralization_reward': 0.3060809737940586,
#                             'utility': 0.2610552150878087,
#                             'shopping': 0.7741935483870968,
#                             'working': 0.6774193548387096,
#                             'education': 0.8709677419354839,
#                             'medical care': 0.7741935483870968,
#                             'entertainment': 0.6451612903225806}}
# (3.952385777275996,
#  {'road_network': -1.0,
#   'life_circle': 0.7636911454638966,
#   'greenness': 0.8976211954204096,
#   'road_network_info': {},
#   'life_circle_info': {'life_circle_15min': 0.9612903225806452,
#    'life_circle_10min': 0.7483870967741937,
#    'life_circle_5min': 0.3548387096774194,
#    'decentralization_reward': 0.3060809737940586,
#    'utility': 0.2610552150878087,
#    'shopping': 0.7741935483870968,
#    'working': 0.6774193548387096,
#    'education': 0.8709677419354839,
#    'medical care': 0.7741935483870968,
#    'entertainment': 0.6451612903225806}})

# %%
env.visualize()

# %%
env.visualize_road_and_boundary()
